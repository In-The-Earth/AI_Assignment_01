# %%
from sklearn.tree import DecisionTreeClassifier as DC
from sklearn.tree import DecisionTreeRegressor as DR
import pandas as pd

# %%
food = pd.read_csv('indian_food.csv')

# %%
food
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
food = food.fillna(-1)

# %%
food.loc[:,"ingredients"].str.split(", ")
# food.loc[len(food.ingredients.str.split(", ")) == 1]
# Out:
# 0                      [Maida flour, yogurt, oil, sugar]
# 1                              [Gram flour, ghee, sugar]
# 2         [Carrots, milk, sugar, ghee, cashews, raisins]
# 3      [Flour, ghee, kewra, milk, clarified butter, s...
# 4      [Milk powder, plain flour, baking powder, ghee...
#                              ...
# 250            [Glutinous rice, black sesame seeds, gur]
# 251    [Coconut milk, egg yolks, clarified butter, al...
# 252    [Cottage cheese, dry dates, dried rose petals,...
# 253    [Milk powder, dry fruits, arrowroot powder, al...
# 254    [Brown rice, fennel seeds, grated coconut, bla...
# Name: ingredients, Length: 255, dtype: object

# %%
food['ingredient_1'] = food.loc[:,"ingredients"].str.split(", ").str[0]
food['ingredient_2'] = food.loc[:,"ingredients"].str.split(", ").str[1]
food['ingredient_3'] = food.loc[:,"ingredients"].str.split(", ").str[2]
food['ingredient_4'] = food.loc[:,"ingredients"].str.split(", ").str[3]
food['ingredient_5'] = food.loc[:,"ingredients"].str.split(", ").str[4]
food['ingredient_6'] = food.loc[:,"ingredients"].str.split(", ").str[5]
food['ingredient_7'] = food.loc[:,"ingredients"].str.split(", ").str[6]
food['ingredient_8'] = food.loc[:,"ingredients"].str.split(", ").str[7]

# %%
food
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
food = food.fillna(-1)

# %%
food
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...
